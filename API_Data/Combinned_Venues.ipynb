# %%
import pandas as pd

# %%
# Read the Google venue data from CSV
google_venues = pd.read_csv('google_venues.csv')

# Read the Yelp venue data from CSV
yelp_venues = pd.read_csv('yelp_venues.csv')

# Merge the data based on common attributes (e.g., venue name, address, etc.)
merged_venues = pd.merge(google_venues, yelp_venues, on=['Venue Name'], how='inner')

# Print the merged data

merged_venues
# Out:
#                      Venue Name  \
# 0                         Elisa
# 1                         Elisa
# 2                         Elisa
# 3                         Elisa
# 4                         Elisa
# ...                         ...
# 1211  Showcase Restaurant & Bar
# 1212  Showcase Restaurant & Bar
# 1213  Showcase Restaurant & Bar
# 1214  Showcase Restaurant & Bar
# 1215  Showcase Restaurant & Bar
#
#                                                 Address  Average Rating_x  \
# 0       1109 Hamilton St, Vancouver, BC V6B 5P6, Canada               4.5
# 1       1109 Hamilton St, Vancouver, BC V6B 5P6, Canada               4.5
# 2       1109 Hamilton St, Vancouver, BC V6B 5P6, Canada               4.5
# 3       1109 Hamilton St, Vancouver, BC V6B 5P6, Canada               4.5
# 4       1109 Hamilton St, Vancouver, BC V6B 5P6, Canada               4.5
# ...                                                 ...               ...
# 1211  1122 W Hastings St, Vancouver, BC V6E 4J6, Canada               4.2
# 1212  1122 W Hastings St, Vancouver, BC V6E 4J6, Canada               4.2
# 1213  1122 W Hastings St, Vancouver, BC V6E 4J6, Canada               4.2
# 1214  1122 W Hastings St, Vancouver, BC V6E 4J6, Canada               4.2
# 1215  1122 W Hastings St, Vancouver, BC V6E 4J6, Canada               4.2
#
#       Review Count_x                SkyTrain Station_x  Latitude_x  \
# 0               1836        Broadway-City Hall Station   49.275964
# 1               1836             Vancouver City Centre   49.275964
# 2               1836  King Edward Station @ Platform 1   49.275964
# 3               1836              Marine Drive Station   49.275964
# 4               1836                         Granville   49.275964
# ...              ...                               ...         ...
# 1211             317                     Lake City Way   49.287858
# 1212             317                       King George   49.287858
# 1213             317                   Renfrew Station   49.287858
# 1214             317                   Gilmore Station   49.287858
# 1215             317                          Columbia   49.287858
#
#       Longitude_x                         ID_x Source_x  Average Rating_y  \
# 0     -123.121413  ChIJhcHC8TBzhlQRPsVWKk8ZNJQ   Google               4.0
# 1     -123.121413  ChIJhcHC8TBzhlQRPsVWKk8ZNJQ   Google               4.0
# 2     -123.121413  ChIJhcHC8TBzhlQRPsVWKk8ZNJQ   Google               4.0
# 3     -123.121413  ChIJhcHC8TBzhlQRPsVWKk8ZNJQ   Google               4.0
# 4     -123.121413  ChIJhcHC8TBzhlQRPsVWKk8ZNJQ   Google               4.0
# ...           ...                          ...      ...               ...
# 1211  -123.120336  ChIJUwY964NxhlQRslxEl4a2VZM   Google               4.0
# 1212  -123.120336  ChIJUwY964NxhlQRslxEl4a2VZM   Google               4.0
# 1213  -123.120336  ChIJUwY964NxhlQRslxEl4a2VZM   Google               4.0
# 1214  -123.120336  ChIJUwY964NxhlQRslxEl4a2VZM   Google               4.0
# 1215  -123.120336  ChIJUwY964NxhlQRslxEl4a2VZM   Google               4.0
#
#       Review Count_y Primary Category           SkyTrain Station_y  \
# 0                193      Steakhouses  Yaletown-Roundhouse Station
# 1                193      Steakhouses  Yaletown-Roundhouse Station
# 2                193      Steakhouses  Yaletown-Roundhouse Station
# 3                193      Steakhouses  Yaletown-Roundhouse Station
# 4                193      Steakhouses  Yaletown-Roundhouse Station
# ...              ...              ...                          ...
# 1211             127          Seafood                      Burrard
# 1212             127          Seafood                      Burrard
# 1213             127          Seafood                      Burrard
# 1214             127          Seafood                      Burrard
# 1215             127          Seafood                      Burrard
#
#       Distance to Station  Longitude_y  Latitude_y                    ID_y  \
# 0              162.728202  -123.121361   49.275956  rVuC98hyTNLaxtr5Y8rH9A
# 1              162.728202  -123.121361   49.275956  rVuC98hyTNLaxtr5Y8rH9A
# 2              162.728202  -123.121361   49.275956  rVuC98hyTNLaxtr5Y8rH9A
# 3              162.728202  -123.121361   49.275956  rVuC98hyTNLaxtr5Y8rH9A
# 4              162.728202  -123.121361   49.275956  rVuC98hyTNLaxtr5Y8rH9A
# ...                   ...          ...         ...                     ...
# 1211           259.524694  -123.120441   49.287986  WPrY9K874pABkAqSxO17nw
# 1212           259.524694  -123.120441   49.287986  WPrY9K874pABkAqSxO17nw
# 1213           259.524694  -123.120441   49.287986  WPrY9K874pABkAqSxO17nw
# 1214           259.524694  -123.120441   49.287986  WPrY9K874pABkAqSxO17nw
# 1215           259.524694  -123.120441   49.287986  WPrY9K874pABkAqSxO17nw
#
#                                                     URL Source_y
# 0     https://www.yelp.com/biz/elisa-vancouver-2?adj...     Yelp
# 1     https://www.yelp.com/biz/elisa-vancouver-2?adj...     Yelp
# 2     https://www.yelp.com/biz/elisa-vancouver-2?adj...     Yelp
# 3     https://www.yelp.com/biz/elisa-vancouver-2?adj...     Yelp
# 4     https://www.yelp.com/biz/elisa-vancouver-2?adj...     Yelp
# ...                                                 ...      ...
# 1211  https://www.yelp.com/biz/showcase-restaurant-a...     Yelp
# 1212  https://www.yelp.com/biz/showcase-restaurant-a...     Yelp
# 1213  https://www.yelp.com/biz/showcase-restaurant-a...     Yelp
# 1214  https://www.yelp.com/biz/showcase-restaurant-a...     Yelp
# 1215  https://www.yelp.com/biz/showcase-restaurant-a...     Yelp
#
# [1216 rows x 19 columns]

# %%
# View null values in each column
null_values = merged_vanues.isnull().sum()

# %%
#null_values

# %%
data_types = merged_venues.dtypes

# %%
#data_types

# %%
# Find duplicated values in the DataFrame
duplicates = merged_venues[merged_data.duplicated()]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [Venue Name, Address, Average Rating_x, Review Count_x, SkyTrain Station_x, Latitude_x, Longitude_x, ID_x, Source_x, Average Rating_y, Review Count_y, Primary Category, SkyTrain Station_y, Distance to Station, Longitude_y, Latitude_y, ID_y, URL, Source_y]
# Index: []

# %%
na_values = merged_venues.isna().sum()

# %%
#na_values

# %%
unique_values = merged_venues['Venue Name'].unique()

# %%
unique_values
# Out:
# array(['Elisa', 'Nightingale', 'Joe Fortes Seafood & Chop House',
#        'Glowbal', 'Hawksworth Restaurant', 'Provence Marinaside',
#        'Five Sails Restaurant', 'Rogue Kitchen & Wetbar',
#        'Blue Water Cafe', 'Bacaro', "Cioppino's Mediterranean Grill",
#        '1931 Gallery Bistro', 'Alouette Bistro', 'Heritage Asian Eatery',
#        'Bacchus Restaurant & Lounge', "Hy's Steakhouse & Cocktail Bar",
#        'JOEY Burrard', "Manoush'eh", 'Showcase Restaurant & Bar'],
#       dtype=object)
