# %%
import os
import json
import requests
import pandas as pd
import time

# %%
google_place = os.environ["GOOGLE_API"]

# %%
# SkyTrain station information is retrieved from the csv file
SkyTrainDF = pd.read_csv('../API_Data/skytrain_stations.csv')

# %%
SkyTrainDF
# Out:
#                                 Name  Rating  Number of Ratings  \
# 0         Broadway-City Hall Station     4.1                 90
# 1              Vancouver City Centre     4.3                146
# 2   King Edward Station @ Platform 1     4.0                 36
# 3               Marine Drive Station     4.2                 91
# 4                          Granville     4.0                 89
# 5            Olympic Village Station     4.1                 54
# 6                            Burrard     4.2                181
# 7                  Sea Island Centre     3.5                 13
# 8                  Stadium-Chinatown     3.6                158
# 9                          Templeton     4.1                 38
# 10                        Waterfront     4.2                  9
# 11       Commercial-Broadway Station     4.1                213
# 12                    Rupert Station     4.0                 42
# 13       Langara-49th Avenue Station     4.2                 37
# 14              Oakridge-41st Avenue     3.7                 44
# 15                   Nanaimo Station     4.0                 69
# 16               King Edward Station     4.3                  6
# 17                Waterfront Station     4.4                 39
# 18                       Yvr–Airport     4.3                242
# 19                Bridgeport Station     4.2                174
# 20                 Royal Oak Station     4.2                 70
# 21         Main Street-Science World     3.8                 86
# 22       Yaletown-Roundhouse Station     4.4                107
# 23                         Patterson     4.3                 73
# 24                 Joyce–Collingwood     4.0                118
# 25               29th Avenue Station     3.9                 51
# 26                   Gateway Station     3.8                 79
# 27                     Lake City Way     3.5                 22
# 28                       King George     4.1                169
# 29                   Renfrew Station     3.8                 31
# 30                   Gilmore Station     4.0                 55
# 31                          Columbia     3.6                 76
#
#                        Place ID   Latitude   Longitude
# 0   ChIJQx4neN1zhlQRdHFbwLLpxeM  49.262997 -123.114541
# 1   ChIJ04sXE39xhlQR1Woi1gmeQXY  49.282469 -123.118613
# 2   ChIJifoZXPJzhlQRtHmyjDhlNAc  49.249187 -123.115857
# 3   ChIJ9_pZvfZ0hlQRtF0YmDWM4lI  49.209670 -123.117020
# 4   ChIJFxdoy3hxhlQRXYS-3DIa4Sk  49.283292 -123.116134
# 5   ChIJlfAnGNxzhlQR-C1WKlNCF0g  49.266540 -123.115620
# 6   ChIJWWb7iIFxhlQRBL4QZPdZs4I  49.285553 -123.120204
# 7   ChIJfdGuxM10hlQRc5O28XA1Muk  49.193046 -123.157890
# 8   ChIJOd5wkHtxhlQRZ-hsRW79874  49.279642 -123.109815
# 9   ChIJJ7z-3MR0hlQRdu2zx6WWbTc  49.196481 -123.146402
# 10  ChIJM9MPgXhxhlQRjb_Uo61XCzw  49.285166 -123.114266
# 11  ChIJ8StlKUlxhlQRgRkkBulg4wE  49.262623 -123.069237
# 12  ChIJxZLLJdJ2hlQRzxwlgSLhUC8  49.260712 -123.033372
# 13  ChIJLSVo4WR0hlQRQEdtPMFv4Is  49.226229 -123.116080
# 14  ChIJO7ZJ03B0hlQRBgDgZxkWzqs  49.233155 -123.116645
# 15  ChIJjXotZLB2hlQRboiC0FUCIDI  49.248278 -123.055917
# 16  ChIJpTCiXvJzhlQRZ4RhjNDsCsI  49.249187 -123.115859
# 17  ChIJfao2c3hxhlQRbXjQ5cpu4qI  49.285680 -123.111770
# 18  ChIJgfLj0DULhlQRAQ0Vh1RJ-uY  49.194209 -123.178273
# 19  ChIJLwv_KOF0hlQRAVVuBfsTO_A  49.195533 -123.126057
# 20  ChIJQ6kjUkR2hlQRwwPRht1HELE  49.220074 -122.988473
# 21  ChIJN4y6GGRxhlQR6nGXK2J2_lw  49.273172 -123.100350
# 22  ChIJ9YbkH9dzhlQRPKDbvBamvco  49.274537 -123.121940
# 23  ChIJdyQeH_V2hlQRoUk2-teHzGo  49.229759 -123.012662
# 24  ChIJCQNPh5R2hlQRYPlAT17spvw  49.238373 -123.031758
# 25  ChIJvW9sD7x2hlQRgErVyf-VarU  49.244280 -123.046110
# 26  ChIJc1Wc0ofXhVQRWtqqSb7Koys  49.198967 -122.850710
# 27  ChIJUXG1MHl3hlQRk3MY922GSBM  49.254600 -122.939180
# 28  ChIJtYoaNNHZhVQRlbX75cwScE0  49.182791 -122.844797
# 29  ChIJSdKSnMt2hlQRKU04gT2FHAg  49.258903 -123.045378
# 30  ChIJD1vYOCl3hlQRCLbLB2uo_mQ  49.264960 -123.013646
# 31  ChIJY1MTnHLYhVQR4uMFvzwjXBk  49.204825 -122.906120

# %% [markdown]
# ## Google Places API Request
# Due to limitations placed by Google, 3 pages of 20 results each will be retrieved for each SkyTrain station. The total number of restaurants retrieved from Google Places ends up at 709.
#
# Some information that was collected from Yelp could not be collected from Google Places in the same way. URL, Category, and distance from the station will remain absent from the data collected via Google Places.

# %%
# Define API key and endpoint
url = 'https://maps.googleapis.com/maps/api/place/textsearch/json'

# Initialize an empty list to store venue details
venue_details = []

# Iterate over each station to retrieve coordinates and name
for station_index, station in SkyTrainDF.iterrows():
    station_latitude = str(
        station['Latitude']
    )
    station_longitude = str(
        station['Longitude']
    )
    station_name = str(
        station['Name']
    )
    # Define the parameters for request
    params = {
        'query': f'Restaurants near SkyTrain {station_name} Vancouver',
        'type': 'restaurant',
        'radius': 500,  # Radius in meters
        'location': { 'lat': station_latitude, 'lng': station_longitude},
        'key': google_place
    }

    # Send the initial request
    response = requests.get(url, params=params)

    # Parse the response as JSON
    data = response.json()


    # Handle the response data
    if response.status_code == 200:
        results = data['results']

        for result in results:
            name = result['name']
            address = result['formatted_address']
            rating = result.get('rating', 'N/A')
            review_count = result['user_ratings_total']
            place_id = result['place_id']
            location = result['geometry']['location']
            latitude = location['lat']
            longitude = location['lng']
            skytrain_station = station_name

            venue_details.append({
                'Venue Name': name,
                'Address': address,
                'Average Rating': rating,
                'Review Count': review_count,
                'SkyTrain Station': station_name,
                'Latitude': latitude,
                'Longitude': longitude,
                'ID': place_id,
                'Address': address,
                'Source': 'Google'
            })

        # Check if there are more results and retrieve them using pagination
        while 'next_page_token' in data:
            next_page_token = data['next_page_token']
            params['pagetoken'] = next_page_token

            # allow the next page token to become valid
            time.sleep(3)

            # Send the next page request
            response = requests.get(url, params=params)

            # Parse the response as JSON
            data = response.json()

            if response.status_code == 200:
                results = data['results']

                for result in results:
                    name = result['name']
                    address = result['formatted_address']
                    rating = result.get('rating', 'N/A')
                    review_count = result['user_ratings_total']
                    place_id = result['place_id']
                    location = result['geometry']['location']
                    latitude = location['lat']
                    longitude = location['lng']
                    skytrain_station = station_name
                        
                    venue_details.append({
                        'Venue Name': name,
                        'Address': address,
                        'Average Rating': rating,
                        'Review Count': review_count,
                        'SkyTrain Station': station_name,
                        'Latitude': latitude,
                        'Longitude': longitude,
                        'ID': place_id,
                        'Address': address,
                        'Source': 'Google'
                    })
            else:
                print('Request failed with status code:', response.status_code)
    else:
        print('Request failed with status code:', response.status_code)

# Create a DataFrame from the station details list
google_venues = pd.DataFrame(venue_details)

# the DataFrame
#google_rest

# %% [markdown]
# ## Results
# Due to the way that Google Places prioritizes results, a high average rating seems to seriously skew what is returned from the API request. This results in restaurants that are well regarded showing up several times in the data, limitting the overall depth.
#
# No option to filter the GET request to disregard rating makes this an issue that cannot be reasonably resolved.

# %%
google_venues.to_csv('../API_Data/google_venues.csv', index=False)

# %%
google_venues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1907 entries, 0 to 1906
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Venue Name        1907 non-null   object
#  1   Address           1907 non-null   object
#  2   Average Rating    1907 non-null   float64
#  3   Review Count      1907 non-null   int64
#  4   SkyTrain Station  1907 non-null   object
#  5   Latitude          1907 non-null   float64
#  6   Longitude         1907 non-null   float64
#  7   ID                1907 non-null   object
#  8   Source            1907 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 134.2+ KB

# %%
uniques = google_venues['Venue Name'].unique()
uniques
# Out:
# array(['Rogue Kitchen & Wetbar', 'Kamei on Broadway', 'Marulilu Café',
#        'Chambar Restaurant', 'Saku Broadway', "Salmon n' Bannock",
#        'Nightingale', 'Cactus Club Cafe Broadway + Ash',
#        'Suika Japanese Restaurant', 'A.BENTO',
#        'Shizenya Restaurant on Broadway', 'Dynasty Seafood Restaurant',
#        'Stages Restaurant & Lounge', 'A&W Canada', 'Peaceful Restaurant',
#        'Chipotle Mexican Grill', 'Kim Son Vietnamese Food', 'Yolks',
#        'Thai Away Home at City Square', 'Glowbal', 'Pho Extreme Xe Lua',
#        "McDonald's", 'White Spot Dunsmuir', 'Shanghai Lu Restaurant',
#        'Sauzzy Thai', 'Cibo Trattoria', 'Basil Box', 'Sushi Dragon',
#        'Tractor Everyday Healthy Foods - Ash & Broadway',
#        'Heritage Asian Eatery', 'Eh! Restaurant',
#        'Cilantro Indian Cuisine',
#        'Johnny’s on Oak Restaurant Vancouver (Best Neighbours Restaurant)',
#        'P2B Restaurant + Bar', 'Falafel King Mediterranean Food',
#        'Diva at the Met', 'Italian Kitchen', 'Paramount Fine Foods',
#        'Teya Grill', 'Aladdin Café', 'Sushi California', 'Bellaggio Cafe',
#        '1931 Gallery Bistro', 'Fatburger West Broadway',
#        'Eat Bar & Patio Haraheri', 'B House Restaurant',
#        'Mosaic Grille & Bar', 'Pret A Manger',
#        'Cactus Club Cafe Bentall 5', 'JOEY Burrard', 'Sala Thai',
#        'City 1 Cafe', 'Eat Chicken Wraps', 'Jollibee',
#        'Earls Kitchen + Bar', 'NaMì Food Cart',
#        'Thai Express Restaurant Vancouver', 'Mazahr Lebanese Kitchen',
#        'Tap & Barrel • Convention Centre', 'BC Kitchen', 'BOTANIST',
#        'Hungry Guys Kitchen & Bar',
#        'Fiorino, Italian Street Food Chinatown Vancouver',
#        'White Spot Granville & Drake', 'Holy Chow', 'ARC RESTAURANT',
#        'Burgoo', 'per se Social Corner', 'Miku Vancouver',
#        'Five Sails Restaurant', "Cardero's Restaurant",
#        'Hawksworth Restaurant', 'Mott 32 Vancouver',
#        'Top Of Vancouver Revolving Restaurant',
#        'Prestons Restaurant + Lounge Vancouver',
#        'Notch8 Restaurant & Bar', 'Ebi-Ten', 'The Templeton',
#        'CinCin Ristorante + Bar', 'Pick & Chews', 'Minami',
#        'Cavo Bar+Kitchen', 'Happy Noodle House', 'Cafe Il Nido',
#        'Gotham Steakhouse & Cocktail Bar', 'Tractor Foods',
#        'Viet Sub Vietnamese Cuisine', 'Kissa Tanto',
#        'Cactus Club Cafe Coal Harbour', 'The Flying Pig Yaletown',
#        'Fable Diner & Bar', 'Pholicious 🍜 Vietnamese 🍜 Restaurant',
#        'Mumbai Local Restaurant', 'De Dutch',
#        'Holts Café | Contemporary Canadian Cuisine', 'PiDGiN Restaurant',
#        'C|PRIME Modern Italian Steak and Wine',
#        'Showcase Restaurant & Bar', 'Kim Express',
#        'Mandarin Hong Kong Cafe 文華餐廳', 'Seasons in the Park',
#        'Lunch Lady', 'JOEY Bentall One', 'Valendine', "Rice 'N Spice",
#        'Osaka Sushi', 'Naruto Sushi', 'Boulevard Kitchen & Oyster Bar',
#        'Red Robin Gourmet Burgers and Brews',
#        'Sun Garden Chinese Restaurant', 'Sushi TonTon', 'Zaatar w Zeit',
#        'Flaming Wok', 'MrBeast Burger',
#        'Kamei Royale Japanese Restaurant',
#        'Mr. Shawarma Vancouver Shawarma and Cheesesteak, Burger, and Falafel',
#        'PHAT Deli & Catering (Royal Centre)', 'Pink Elephant Thai',
#        'Freshslice Pizza',
#        'Neptune Palace Seafood Restaurant (Vancouver)', 'Panago Pizza',
#        'Bubble Waffle Cafe (Cambie)', 'White Spot (Best Western)',
#        'Dublin Crossing - Vancouver', "Triple O's", "Wendy's", 'Subway',
#        'Thai Son Restaurant (Marine Dr, Vancouver)', 'Hi Five Chicken',
#        'Kitchen Table Group', 'Flamingo Chinese Restaurant', 'JOY CAFE',
#        'New Fishport Seafood Bistro', 'Tim Hortons',
#        'Easy Italian Food Cooking', 'Pho Zen Vietnamese Cuisine',
#        'OutTakes Backstage Bistro', "Cafe de l'Orangerie",
#        'Fat Boy Kitchen', "Wo's Chinese Restaurant 金穗園美食",
#        'To Dine for Eatery', 'SeaHouse Restaurant', 'Blue Water Cafe',
#        "Mahony's Tavern Convention Centre",
#        'Victoria Chinese Restaurant 悅海大酒家', 'Mr.Shawarma Robson Location',
#        'Black+Blue', 'Ancora Waterfront Dining and Patio - False Creek',
#        'Green Leaf Salad Bar', 'Five Guys', 'Thai Away Home on Granville',
#        'Heaven Bar& grill', 'Hungry Guys Kitchen', 'Mr Greek Donair Town',
#        'El Furniture Warehouse Granville',
#        'The Edge Social Grille & Lounge', 'O Sushi Downtown Vancouver',
#        'bbq Chicken & Pub Granville', 'Good Co. Granville',
#        'Megabite Granville St.', 'The Dime on Granville',
#        'The Marquis Bar and Grill', 'Mount Everest Kitchen & Grill',
#        'Locus Restaurant & Lounge', "Joon's Kitchen",
#        'Dockside Restaurant', 'Rayhan', "Dylan's", "Vij's",
#        'St Regis Bar & Grill', 'Bonjour Banh Mi', 'The Meat Up Vancouver',
#        'Tap & Barrel • Bridges', 'Bin 4 Burger Lounge', 'Sen Pad Thai',
#        'Grab N Go Yaletown', 'The Stable House Bistro', 'Unwind',
#        'Ming Tak Hong Kong Style Restaurant',
#        'Jasmine Flower Shanghai Cuisine',
#        'The Keg Steakhouse + Bar - Dunsmuir', 'Popina Canteen',
#        'Mirchi Restaurant', 'Sprig Contemporary Greek Kitchen',
#        'Cafe Medina', "Paul's Omelettery Restaurant",
#        'Fritz European Fry House', 'Caffe Barney on Granville',
#        'Breakfast Table South Granville',
#        'Tap & Barrel • Olympic Village', 'The Flying Pig Olympic Village',
#        'Tractor Everyday Healthy Foods - Olympic Village', 'Bao Down OV',
#        "Hon's Wonton House - Olympic Village", 'Gusto A Taste of Italy',
#        'CRAFT Beer Market False Creek', 'Nook',
#        "Mahony's Tavern False Creek", 'Padre Taco', 'Ophelia',
#        'Food Hall by ZUBU', 'Yanaki Sushi', 'Banana Leaf on Davie',
#        'Pho Quynh Express', "Frankie's Italian Vancouver",
#        'Super Chef Grill', 'Frying Pan food truck',
#        'Shabusen Yakiniku House', 'La Taqueria Pinche Taco Shop',
#        'Sushi Yan Japanese Restaurant', 'Sushi Tendo', 'Argo Cafe',
#        'Papaya Hut Restaurant', 'Unchai Restaurant', 'Brass Fish Tavern',
#        'Le Crocodile', "Maxine's Cafe & Bar", 'Tacofino Oasis',
#        'Fortune Express', 'Novo Italian', 'Kuroi Sushi', '#e food',
#        'Mi Casa Mexicana', 'WE GRILL', 'My Toan',
#        'Fatburger Waterfront Centre', 'BASHA', 'BurgerHolic', 'Café One',
#        'Famous Wok', 'Sushi Coen', 'Daikichi Sushi Shop',
#        'Tim Kee Kitchen Cantonese & Szechuan Cuisine',
#        'Mazuya Sushi Restaurant', 'The Ballyhoo Public House',
#        'Hula Poke Waterfront Centre', 'Sushi Flamingo', 'Alouette Bistro',
#        'C&T Fried Chicken 大鸡炸鸡', 'Japadog', "Nando's PERi-PERi",
#        "St. Paul's Hospital Cafeteria - Balance Eatery", 'Bánh Shop',
#        'Canucks Bar and Grill', "Pajo's Yvr Airport",
#        "Pajo's YVR Inter. Departure Building Level 3",
#        'Stanley Park Tap House', 'Urban Crave', 'Sea Harbour Restaurant',
#        'Thai Hang', 'Rice Tales', 'Neptune Wonton Noodle',
#        "Church's Chicken", 'Freshii', 'Lift @yvr', 'Globe@YVR',
#        'Tin Tin Seafood Harbour', "Monk's Grill",
#        "Carmelo's Ristorante Italiano", 'Sal y Limón Mexican Cuisine',
#        'the apron', 'Burger King', 'Milltown Bar & Grill',
#        'Hanami Express', 'AFTERNOON TEA',
#        'Ryuu Japanese Kitchen (YVR Outlet)', 'Bubble Waffle Cafe',
#        "Fisherman's Terrace Seafood Restaurant", 'Donair Dude',
#        'Ipoh Malay Cuisine 怡堡马来美食', 'Food Folk Eatery',
#        'Red Star Seafood Restaurant', 'BESPOKE & SUSHI', 'BiBo Pizzeria',
#        'KFC', 'Chef Tony Seafood Restaurant', 'Shanghai Morning',
#        'Ikura Sushi', "Hugo's Churros & Tacos", 'Hula Poke',
#        'Man Ri Sung Restaurant', 'Chef Hung Taiwanese Beef Noodle',
#        'Nukkad Indian Street Eats', 'Peko Peko Cuisine Ltd',
#        'Great Grain Food', 'Mozza Restaurant and Lounge', "Carl's Jr.",
#        'Mamalee - Chinatown', "Devil's Elbow Ale and Smoke House",
#        'Sai Woo', 'Pizzeria Ludica', 'Jade Dynasty Restaurant',
#        'DD MAU Chinatown', 'Fat Mao Noodles (Chinatown)', 'Jam Cafe',
#        'Chinatown BBQ', 'Ryo Japanese Food', 'TAKO - Taqueria Korean',
#        'Congee Noodle Delight', 'Gain Wah Restaurant Ltd', 'Bao Bei',
#        'TINA Vietnamese', 'Floata Seafood Restaurant 富大海鮮酒家',
#        'Five Fifty', "Maxim's Bakery & Restaurant Chinatown",
#        'Torimaru Ramen', 'La Taqueria Pinche Taco', 'Bali Thai',
#        'Autostrada Osteria Downtown', 'Tokyo In April',
#        'Giant Panda Szechuan Cuisine', 'Einstein Wrap House',
#        'Little Bangkok Thai Kitchen 2', "Kent's Kitchen",
#        'Manpuku Bento Japanese Lunchbox Takeout Chinatown Vancouver',
#        'PappaRoti', 'Tsuki Sushi Bar', 'Kam Wai Dim Sum 金 威 點 心',
#        "JJ's Restaurant at Vancouver Community College",
#        'Charisma Social Club House', 'The Magnet', 'Pizza Coming Soon',
#        'The Boss Bakery & Restaurant Chinatown', 'Sushi Den', 'Qieu Cafe',
#        'Prime Time Chicken and Chinese Food', 'Phnom Penh Restaurant',
#        'TacoTime International Village', 'Calabash Bistro',
#        'Boston Pizza', '金边小馆', 'Deer Alley Restaurant 德意小館',
#        'Chit Chat Burger Bar', 'Fresh Donair', 'The Tipper Restaurant',
#        'Bacaro', 'Symphonie Restaurant', 'Mr. Arancino', 'The Parlour',
#        "LanaLou's Restaurant", 'Moxies West Georgia Restaurant',
#        'Fatburger Granville', 'Al Porto Ristorante',
#        'Provence Marinaside', 'Water St. Café', 'Momo Sushi',
#        'acquafarina', 'Nuba in Gastown', 'Stock & Supply',
#        'Pourhouse Restaurant', 'Bekon Loft + Lounge',
#        'Skydine Events Inc. dba Dinner in the Sky Canada',
#        'KAIBA BAR & GRILL INC', 'Harbour Spoon', 'Wing Ga Ma',
#        'Lucha Libre Taqueria', 'Is That French', 'The Grill',
#        'Brix and Mortar', "Cioppino's Mediterranean Grill", "Kyle's Cafe",
#        "Hon's Wonton House - Broadway Station", 'ChongQing On Commercial',
#        'Bates Restaurants Ltd', "Bon's Off Broadway", 'Song (by Kin Kao)',
#        'Collective Goods Bistro & Grocer', 'Bar Corso', 'Absinthe Bistro',
#        "Daddy's Kitchen", 'The Dime', "Uncle Fatih's Pizza - COMMERCIAL",
#        'The Burrow - formerly Bandidas Taqueria', 'Baby Dhal Roti Shop',
#        'Kishimoto Japanese Restaurant', 'Tangent', 'Commercial Sushi',
#        'The Charlatan', 'Dingding Restaurant', 'Chancho Tortilleria',
#        'S2 Cafe House', "It's Okay", 'Mango Junction Pizza',
#        'Grand Honour Restaurant', "Tao's Kitchen",
#        'Homer St. Cafe and Bar', 'H-Mart Food Court',
#        'Kosoo Korean Restaurant Chicken & BBQ - 2nd Branch',
#        'Llh Eatery Inc', 'Student Union Food Bar',
#        "Triple O's Langara College", 'Samurai Sushi House',
#        'Himalaya Restaurant', 'East is East', 'So Hyang Korean Cuisine',
#        'Café FortyOne', 'Autostrada Osteria Main Street',
#        'All India Sweets & Restaurant', 'MeeT on Main',
#        'Original Tandoori Kitchen', 'Main Kabab Hut', 'Sushi Bar Ajisai',
#        'SAMURAI SUSHI ON FRASER', 'Northern Cafe', 'Pizza Garden',
#        'Pho Hoa + Jazen Tea (Oak)', 'Sip Bowl', 'Orange Corner',
#        'Legato Cafe', 'Minerva’s Restaurant', "Jess' Restaurant",
#        'Pho Tan Vietnamese Restaurant Beef Noodle Soup & Bubble Tea',
#        'Baan Wasana Thai Restaurant', 'Golden Ocean Seafood Restaurant',
#        'Fish Café', 'Kerrisdale Nakamura Japanese Cuisine', 'ASA Sushi',
#        "Lok's Chinese Restaurant",
#        'Okini Restaurant & Bar (formerly Land & Sea)',
#        'Baoguette Vietnamese Bistro', 'Burrata Pizzeria',
#        'East Side Craft House', 'New Chong Qing Restaurant',
#        '41 Noodle & Rice Pot House', 'Hikari Cafe',
#        'White Spot Kerrisdale', 'Sawasdee Thai Restaurant',
#        'Fable Kitchen', 'Kokoro Tokyo Mazesoba - Kerrisdale', 'Barra 41',
#        'Rocky Mountain Flatbread, Main Street', 'ZUBU Ramen - Kerrisdale',
#        'Sidra’s Pizza', 'Trocadero Pizza & Steak House',
#        'Shiok Singaporean Cuisine', 'Mui Ngo Gai Restaurant',
#        'Sushi Nanaimo', 'White Spot Kingsway', 'The Hide Out Diner',
#        'Green Lettuce', 'Happy Family Restaurant', 'The Red Wagon',
#        'i-Cafe', 'Van Hot Dog', 'Viet House', 'Landmark Hotpot House',
#        'Sushi 7', 'Monsoon Curry Indian Restaurant', 'Baghdad Cafe',
#        'Frying Pan on Denman', 'Food Court & Stops',
#        'Brioche Ristorante & Catering', 'Lift Bar Grill View',
#        'Guu with Otokomae', 'Umi Sushi Express', 'The Poke Guy',
#        'Black Frog Eatery', 'Oceans 999', 'Kita No Donburi',
#        "Pajo's Fish & Chips at YVR Airport",
#        "Salmon n' Bannock - On the Fly", 'The Dirty Apron',
#        'True Burger Co.', 'Euro Cafe', 'JOE & THE JUICE',
#        'Flying Beaver Bar & Grill', 'Free Bird Table & Bar',
#        '75 West Coast Grill', 'Famous Famiglia', "Harold's Kitchen & Bar",
#        'Italian Tomato Restaurant', 'Bruno', 'Sushi Kiwami',
#        'Mean Poutine', 'Trattoria Burnaby', 'WestOak',
#        'Sura Korean Royal Cuisine Restaurant Vancouver',
#        'Tenen Restaurant', 'Kyuzo Japanese Restaurant',
#        'Foodkort Dining Ltd', 'MoMo Sushi Royal Center', 'Torafuku',
#        'Bodega on Main', 'Zarak by Afghan Kitchen',
#        'Superbaba (Vancouver)', 'Pizzeria Farina',
#        "Triple O's Science World", 'A & W Home Of The Burger Family',
#        'Le Tigre', 'Virtuous Pie', 'Pacific Poke',
#        "Kalai's curry kitchen", 'Machete Mexican Ancestral Food',
#        'Published on Main', 'Ekki Sushi', 'Oyster Express',
#        'Saba Foods Yemeni Restaurant', 'Take Urban Cafe', 'Maizal RMF',
#        "L'Abattoir", 'Twisted Fork', 'MeeT in Yaletown',
#        'Robba da Matti (Yaletown)', 'Zab Zaab Thai Cuisine',
#        'Sushi Maro Japanese Restaurant', 'Elisa', 'Capo & The Spritz',
#        'Cactus Club Cafe Yaletown', 'Bistro Sakana Vancouver',
#        'Little Saigon Yaletown', "Rodney's Oyster House",
#        'Saigon Xua Vancouver', 'Tasty Indian Bistro | Yaletown',
#        'Salsa & Agave Mexican Grill', 'Ojik Kimchi Stew',
#        'The Greek By Anatoli', 'Tacofino Yaletown', 'European sausage',
#        'La Terrazza', 'Nuba in Yaletown', 'Hula Poke Yaletown',
#        'Ki Isu Japanese Restaurant', 'Egg Sammie', 'Banter Room',
#        'Hapa Izakaya Yaletown', 'The Loft at Earls Yaletown', 'El Guapo',
#        'Field & Social Yaletown', 'Mapo Pancake House',
#        'The Keg Steakhouse + Bar - Yaletown', 'Fiasco Pizza Company',
#        'Freshbowl', 'Yopo Sweet Mandarin',
#        'Moltaqa Moroccan Restaurant Mainland Street Yaletown',
#        'OEB Breakfast Co.', 'Obanhmi', 'Tutto Restaurant & Bar',
#        'The Italian Chef',
#        '蜀莊 Grand Chinese Yaletown Restaurant (Order from our Website & Save More !)',
#        'Nightshade', 'Sushi Okeya Kyujiro', 'Ignite Pizzeria Yaletown',
#        'Hundy', 'Cafe Amora', "Original Joe's",
#        'The Wine Bar at Provence Marinaside', 'The Stock Room',
#        'Twins Chinese Kitchen', 'Joe Fortes Seafood & Chop House',
#        'The Italians', 'Mangos Kitchen Bar', 'Japanese Bistro Kamome',
#        'Milk and Sugar BBQ Bar', 'Sushi Taku', 'Mr. Pan Pizza',
#        'Pampanga’s Cuisine Home of the Original Sisig', 'Phở Nhuận',
#        'Donair Land', 'Hoa Phuong Do Restaurant',
#        'iSushi Japanese Restaurant',
#        '可爱的新疆 Lovely Uyghur (Order from our website & SAVE MORE!)',
#        'PLATO FILIPINO', 'Kimu Japanese Cuisine', 'Lucky Sheep',
#        'Liberte Cafe & Restaurant', 'chefhyve', 'Super Great Pizza',
#        'Chicko Chicken', 'Joojak Restaurant',
#        'Jambo Grill Tandoor & Paan House', 'Michi Craft Kitchen',
#        'Dog Eat Corndog', 'Truong Thanh Restaurant',
#        '北疆饭店 Beijiang Restaurant (Order from our website & SAVE MORE!)',
#        'Border Burrito', 'Dumpling House', 'Kumare Express',
#        'GreenPrice food & trading ltd', 'Thai Box On Truck',
#        'Kozak Ukrainian Eatery & Mill', 'La Raza Mexican Cuisine',
#        'Sushi Royal House', 'La Piazza Dario', 'ETEA cafe',
#        'Sandy La Chinese Restaurant', 'Kopitiam Malaysia',
#        'Congee Noodle King', 'Viet Mama Cafe', 'Kwan Luck Restaurant',
#        'Ragazzi Pizza Co', 'Donair Affair', 'Metro town', 'Dragon House',
#        'Kung Fu Noodle Kingsway–Joyce', 'Pizza 222', 'Chili Pepper House',
#        'Dharma Garden Veggie Deli', 'Fortune Lamb Dining 鸿羊轩',
#        'Love for Pho',
#        "Max's Restaurant, Cuisine of the Philippines, Vancouver",
#        'Happy Day Cafe', 'Meet Fan', 'Yue Ting Seafood Restaurant',
#        "Church's Texas Chicken", 'Sushi Aji', 'Dragon Crepe',
#        'The Sea House Fish and Chips', 'Mom’s Grilled Cheese Truck',
#        'Vina', 'Gyu King Teppanyaki',
#        'Edo Japan - CF Pacific Centre - Grill and Sushi', 'Quiznos',
#        'Time & Place', 'Birdies Eats & Drinks', 'Happy Valley Food City',
#        'PIER 7 Restaurant + Bar', 'Tokyo Katsu-sand',
#        'Mr. Shawarma Granville Location',
#        'Cactus Club Cafe Station Square', 'The Main', 'Hachibei',
#        'Regal Mansion Cuisine Seafood Restaurant 福臨門海鮮大酒樓',
#        'Browns Socialhouse Queen Elizabeth Theatre (QE Theatre)',
#        'Dutch Wooden Shoe Cafe', 'Restaurant Yugo', 'CHI HOUSE',
#        'bbq Chicken & Pub Main ST', 'Chickpea Restaurant', 'Hot Delivery',
#        '叫了个鸡 Chirpyhut Fried Chicken Vancouver (Buy $30 get $7 off, and Get 20% off for order from our website!)',
#        'The Story Cafe - Eatery & Bar',
#        'Sun Sui Wah Seafood Restaurant 新瑞華海鮮酒家',
#        'Apollonia Greek Restaurant', 'Grand View Szechuan Restaurant',
#        'Corner 23', 'The Arbor Restaurant', 'Sushi Mura',
#        'Royal Seoul House Restaurant', 'Trackers Cafe', 'Belgard Kitchen',
#        'Takara Sushi', 'Aidan’s', "Union Latino's food",
#        'Café Gloucester', 'Soupspoons', 'La Playita Seafood'],
#       dtype=object)
